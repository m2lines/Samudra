# %%
import xarray as xr

# %%
pred = xr.open_zarr("/scratch/sd5313/M2Lines/emulator/Ocean_Emulator/Preds/2024-09-12_ConvNextUNetTrain3Dv021Eval3DhfdsanomsNetZeroHf1975Epochs70Epoch55Years100_10repeat_36_6k_Train_global_3D_Test_global_3D_all_N_train_0_Lateral_Data_025_no_smooth/Pred_lateral_Fast_Data_025_global_3D_all_N_samples_0_rand_seed_1.zarr")
pred
# Out:
# <xarray.Dataset>
# Dimensions:                        (time: 29176, x: 180, y: 360, var: 77)
# Dimensions without coordinates: time, x, y, var
# Data variables:
#     __xarray_dataarray_variable__  (time, x, y, var) float64 dask.array<chunksize=(46, 23, 45, 10), meta=np.ndarray>

# %%
pred = xr.open_zarr("/scratch/sd5313/M2Lines/emulator/Ocean_Emulator/Preds/2024-09-12_ConvNextUNetTrain3Dv021Eval3DhfdsanomsNetZeroHfTempOnlyNoJump3xcc1975Epochs70Epoch55Years100_10repeat_newforce30x_Train_global_3D_Test_global_3D_all_N_train_0_Lateral_Data_025_no_smooth/Pred_lateral_Fast_Data_025_global_3D_all_N_samples_0_rand_seed_1.zarr")
pred
# Out:
# <xarray.Dataset>
# Dimensions:                        (time: 29246, x: 180, y: 360, var: 39)
# Dimensions without coordinates: time, x, y, var
# Data variables:
#     __xarray_dataarray_variable__  (time, x, y, var) float64 dask.array<chunksize=(45, 23, 45, 10), meta=np.ndarray>

# %%
import torch
import time

# Check if GPU is available
device = torch.device("cuda")

# Create large tensors
tensor_size = (10000, 10000)
a = torch.randn(tensor_size, device=device)
b = torch.randn(tensor_size, device=device)

# Run large matrix multiplication in a loop
while True:
    start_time = time.time()
    c = torch.matmul(a, b)
    # Optionally perform some other operations to keep GPU busy
    torch.cuda.synchronize()  # Make sure all operations are finished
    end_time = time.time()
    del c
    torch.cuda.empty_cache()
    # print(f"Iteration {i+1}, Time: {end_time - start_time:.4f} seconds")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 17
#      15 c = torch.matmul(a, b)
#      16 # Optionally perform some other operations to keep GPU busy
# ---> 17 torch.cuda.synchronize()  # Make sure all operations are finished
#      18 end_time = time.time()
#      19 del c
#
# File /ext3/miniconda3/envs/emulator/lib/python3.10/site-packages/torch/cuda/__init__.py:801, in synchronize(device)
#     799 _lazy_init()
#     800 with torch.cuda.device(device):
# --> 801     return torch._C._cuda_synchronize()
#
# KeyboardInterrupt:
