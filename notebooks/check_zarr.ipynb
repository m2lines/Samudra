# %%
import xarray as xr

# %%
Pred_path_0wm = '/scratch/sd5313/M2Lines/emulator/Ocean_Emulator/Preds/2024-10-29_ConvNextUNetTrain3Dv021Eval3DhfdscumintegNofastinoutEpochs70Epoch55_LongRolloutNoForcing_detrendhfdsearlyonly_Train_global_3D_Test_global_3D_all_N_train_0_Lateral_Data_025_no_smooth/Pred_lateral_Fast_Data_025_global_3D_all_N_samples_0_rand_seed_1.zarr' #temp warming .5 w/m2
Pred_path_025wm = '/scratch/sd5313/M2Lines/emulator/Ocean_Emulator/Preds/2024-10-29_ConvNextUNetTrain3Dv021Eval3DhfdscumintegNofastinoutEpochs70Epoch55_LongRollout0_25Wm2annualincrease_detrendhfdsearlyonly_Train_global_3D_Test_global_3D_all_N_train_0_Lateral_Data_025_no_smooth/Pred_lateral_Fast_Data_025_global_3D_all_N_samples_0_rand_seed_1.zarr' #temp warming .5 w/m2
Pred_path_05wm = '/scratch/sd5313/M2Lines/emulator/Ocean_Emulator/Preds/2024-10-29_ConvNextUNetTrain3Dv021Eval3DhfdscumintegNofastinoutEpochs70Epoch55_LongRollout0_5Wm2annualincrease_detrendhfdsearlyonly_Train_global_3D_Test_global_3D_all_N_train_0_Lateral_Data_025_no_smooth/Pred_lateral_Fast_Data_025_global_3D_all_N_samples_0_rand_seed_1.zarr' #all warming .5 w/m2
Pred_path_1wm = '/scratch/sd5313/M2Lines/emulator/Ocean_Emulator/Preds/2024-10-29_ConvNextUNetTrain3Dv021Eval3DhfdscumintegNofastinoutEpochs70Epoch55_LongRollout1Wm2annualincrease_detrendhfdsonly_Train_global_3D_Test_global_3D_all_N_train_0_Lateral_Data_025_no_smooth/Pred_lateral_Fast_Data_025_global_3D_all_N_samples_0_rand_seed_1.zarr' #temp warming 1 w/m2

# %%
pred = xr.open_zarr(Pred_path_0wm)
pred
# Out:
# <xarray.Dataset>
# Dimensions:                        (time: 4788, x: 180, y: 360, var: 39)
# Dimensions without coordinates: time, x, y, var
# Data variables:
#     __xarray_dataarray_variable__  (time, x, y, var) float64 dask.array<chunksize=(5, 45, 90, 10), meta=np.ndarray>

# %%
pred = xr.open_zarr(Pred_path_025wm)
pred
# Out:
# <xarray.Dataset>
# Dimensions:                        (time: 4644, x: 180, y: 360, var: 39)
# Dimensions without coordinates: time, x, y, var
# Data variables:
#     __xarray_dataarray_variable__  (time, x, y, var) float64 dask.array<chunksize=(5, 45, 90, 10), meta=np.ndarray>

# %%
pred = xr.open_zarr(Pred_path_05wm)
pred
# Out:
# <xarray.Dataset>
# Dimensions:                        (time: 4176, x: 180, y: 360, var: 39)
# Dimensions without coordinates: time, x, y, var
# Data variables:
#     __xarray_dataarray_variable__  (time, x, y, var) float64 dask.array<chunksize=(5, 45, 90, 10), meta=np.ndarray>

# %%
pred = xr.open_zarr(Pred_path_1wm)
pred
# Out:
# <xarray.Dataset>
# Dimensions:                        (time: 4536, x: 180, y: 360, var: 39)
# Dimensions without coordinates: time, x, y, var
# Data variables:
#     __xarray_dataarray_variable__  (time, x, y, var) float64 dask.array<chunksize=(5, 45, 90, 10), meta=np.ndarray>

# %%
pred = xr.open_zarr("/scratch/sd5313/M2Lines/emulator/Ocean_Emulator/Preds/2024-10-28_ConvNextUNetTrain3Dv021Eval3DhfdscumintegNofastinoutEpochs70Epoch55_LongRolloutNoForcing_Train_global_3D_Test_global_3D_all_N_train_0_Lateral_Data_025_no_smooth/Pred_lateral_Fast_Data_025_global_3D_all_N_samples_0_rand_seed_1.zarr")
pred
# Out:
# <xarray.Dataset>
# Dimensions:                        (time: 1944, x: 180, y: 360, var: 39)
# Dimensions without coordinates: time, x, y, var
# Data variables:
#     __xarray_dataarray_variable__  (time, x, y, var) float64 dask.array<chunksize=(5, 45, 90, 10), meta=np.ndarray>

# %%
pred = xr.open_zarr("/scratch/sd5313/M2Lines/emulator/Ocean_Emulator/Preds/2024-09-25_ConvNextUNetTrain3Dv021Eval3DhfdsanomsNetZeroHfTempOnly1975Epochs70Epoch55Years100_10repeat_2002_Train_global_3D_Test_global_3D_all_N_train_0_Lateral_Data_025_no_smooth/Pred_lateral_Fast_Data_025_global_3D_all_N_samples_0_rand_seed_1.zarr")
pred
# Out:
# <xarray.Dataset>
# Dimensions:                        (time: 25404, x: 180, y: 360, var: 39)
# Dimensions without coordinates: time, x, y, var
# Data variables:
#     __xarray_dataarray_variable__  (time, x, y, var) float64 dask.array<chunksize=(19, 23, 90, 10), meta=np.ndarray>

# %%
pred = xr.open_zarr("/scratch/sd5313/M2Lines/emulator/Ocean_Emulator/Preds/2024-09-25_ConvNextUNetTrain3Dv021Eval3DhfdsanomsNetZeroHf1975Epochs70Epoch55Years100_10repeat_1998_Train_global_3D_Test_global_3D_all_N_train_0_Lateral_Data_025_no_smooth/Pred_lateral_Fast_Data_025_global_3D_all_N_samples_0_rand_seed_1.zarr")
pred
# Out:
# <xarray.Dataset>
# Dimensions:                        (time: 17082, x: 180, y: 360, var: 77)
# Dimensions without coordinates: time, x, y, var
# Data variables:
#     __xarray_dataarray_variable__  (time, x, y, var) float64 dask.array<chunksize=(19, 23, 45, 20), meta=np.ndarray>
